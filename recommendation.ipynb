# %%
import pandas as pd
import numpy as np
import math
import re
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
from random import randint
import seaborn as sns
from surprise import Reader, Dataset, SVD, evaluate
# %matplotlib inline
sns.set_style("darkgrid")

# %%
dataset = pd.read_csv('./ratings.csv', header = None, names = ['userId','movieId', 'rating'], usecols = [0,1,2],skiprows=1)

# %%
dataset['rating'] = dataset['rating'].astype('float')
print('Ratings Dataset : {}'.format(dataset.shape))
print(dataset.iloc[::5000000, :])
# Out:
# Ratings Dataset : (26024289, 3)
#           userId  movieId  rating
# 0              1      110     1.0
# 5000000    51433     1376     4.0
# 10000000  103170      924     3.0
# 15000000  156028     1918     3.0
# 20000000  207965    89864     4.0
# 25000000  260079      585     3.0

# %%
p = dataset.astype(int).groupby('rating')['rating'].agg(['count'])

print(p)
# Out:
#           count
# rating
# 0        404897
# 1       1246917
# 2       3017798
# 3       8372935
# 4       9169243
# 5       3812499

# %%
userfreq = dataset.groupby('userId')['userId'].size()
print(userfreq[:10])
# Out:
# userId
# 1      27
# 2      22
# 3      10
# 4      62
# 5      26
# 6       4
# 7      53
# 8     113
# 9      84
# 10     13
# Name: userId, dtype: int64

# %%
maxrating = max(list(userfreq))
useridmax = list(userfreq).index(maxrating)
print("Maximum rating given : " + str(maxrating) + " by user with id: " + str(useridmax))
minrating = min(list(userfreq))
useridmin = list(userfreq).index(minrating)
print("Maximum rating given : " + str(minrating) + " by user with id: " + str(useridmin))
# Out:
# Maximum rating given : 18276 by user with id: 45810
# Maximum rating given : 1 by user with id: 44

# %%
datasetmovies = pd.read_csv('./movies.csv', header = None, names = ['movieId','title', 'genres'], usecols = [0,1,2])
datasetmovies.set_index('movieId', inplace = True)

# %%
datasetmovies.head(10)
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# 6                               Heat (1995)
# 7                            Sabrina (1995)
# 8                       Tom and Huck (1995)
# 9                       Sudden Death (1995)
# 10                         GoldenEye (1995)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# 6                              Action|Crime|Thriller
# 7                                     Comedy|Romance
# 8                                 Adventure|Children
# 9                                             Action
# 10                         Action|Adventure|Thriller

# %%
reader = Reader()

# get just top 100K rows for faster run time
data = Dataset.load_from_df(dataset[['userId', 'movieId', 'rating']], reader)
data.split(n_folds=10)

algo = SVD()
evaluate(algo, data, measures=['RMSE', 'MAE'])
# Out:
# C:\Users\nani\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\Users\nani\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ecfd169c7dc0> in <module>()
#       6
#       7 algo = SVD()
# ----> 8 evaluate(algo, data, measures=['RMSE', 'MAE'])
#
# ~\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\evaluate.py in evaluate(algo, data, measures, with_dump, dump_dir, verbose)
#      81
#      82         # train and test algorithm. Keep all rating predictions in a list
# ---> 83         algo.fit(trainset)
#      84         predictions = algo.test(testset, verbose=(verbose == 2))
#      85
#
# ~\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\prediction_algorithms\matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.fit()
#
# ~\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\prediction_algorithms\matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.sgd()
#
# ~\AppData\Local\Continuum\Anaconda3\envs\recommend\lib\site-packages\surprise\trainset.py in all_ratings(self)
#     188         for u, u_ratings in iteritems(self.ur):
#     189             for i, r in u_ratings:
# --> 190                 yield u, i, r
#     191
#     192     def build_testset(self):
#
# KeyboardInterrupt:

# %%
from surprise.prediction_algorithms import SlopeOne
algo1 = SlopeOne()
evaluate(algo1, data, measures=['RMSE', 'MAE'])
# Out:
# Evaluating RMSE, MAE of algorithm SlopeOne.
#
# ------------
# Fold 1
# RMSE: 0.8685
# MAE:  0.6615
# ------------
# Fold 2
# RMSE: 0.8659
# MAE:  0.6597
# ------------
# Fold 3
# RMSE: 0.8660
# MAE:  0.6603
# ------------
# ------------
# Mean RMSE: 0.8668
# Mean MAE : 0.6605
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [0.66151840378977811,
#                              0.65969220537182427,
#                              0.66026198018314119],
#                             'rmse': [0.86852120216184969,
#                              0.86593817952121743,
#                              0.86603639877684468]})

# %%
from surprise.prediction_algorithms import KNNWithMeans
algo1 = KNNWithMeans()
evaluate(algo1, data, measures=['RMSE', 'MAE'])
# Out:
# Evaluating RMSE, MAE of algorithm KNNWithMeans.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8803
# MAE:  0.6742
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8818
# MAE:  0.6752
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8811
# MAE:  0.6751
# ------------
# ------------
# Mean RMSE: 0.8811
# Mean MAE : 0.6749
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'mae': [0.67424925376493527,
#                              0.67524588529266583,
#                              0.67510772895352855],
#                             'rmse': [0.88028112397628977,
#                              0.88182395917468892,
#                              0.88114303000332339]})

# %%
data = Dataset.load_from_df(dataset[['userId', 'movieId', 'rating']], reader)

trainset = data.build_full_trainset()
algo.train(trainset)

# %%
data = Dataset.load_from_df(dataset[['userId', 'movieId', 'rating']], reader)

some = pd.DataFrame([[200000,300,5.0]],columns=['userId','movieId','rating'])
dataset.append(some,ignore_index=True)
# Out:
#          userId  movieId  rating
# 0             1      110     1.0
# 1             1      147     4.5
# 2             1      858     5.0
# 3             1     1221     5.0
# 4             1     1246     5.0
# 5             1     1968     4.0
# 6             1     2762     4.5
# 7             1     2918     5.0
# 8             1     2959     4.0
# 9             1     4226     4.0
# 10            1     4878     5.0
# 11            1     5577     5.0
# 12            1    33794     4.0
# 13            1    54503     3.5
# 14            1    58559     4.0
# 15            1    59315     5.0
# 16            1    68358     5.0
# 17            1    69844     5.0
# 18            1    73017     5.0
# 19            1    81834     5.0
# 20            1    91500     2.5
# 21            1    91542     5.0
# 22            1    92439     5.0
# 23            1    96821     5.0
# 24            1    98809     0.5
# 25            1    99114     4.0
# 26            1   112552     5.0
# 27            2        5     3.0
# 28            2       25     3.0
# 29            2       32     2.0
# ...         ...      ...     ...
# 1048546   10656     1441     4.0
# 1048547   10656     1455     3.0
# 1048548   10656     1463     3.0
# 1048549   10656     1479     4.0
# 1048550   10656     1488     3.0
# 1048551   10656     1493     3.0
# 1048552   10656     1500     5.0
# 1048553   10656     1518     2.0
# 1048554   10656     1527     5.0
# 1048555   10656     1541     2.0
# 1048556   10656     1542     4.0
# 1048557   10656     1552     3.0
# 1048558   10656     1554     2.0
# 1048559   10656     1562     2.0
# 1048560   10656     1566     3.0
# 1048561   10656     1569     3.0
# 1048562   10656     1573     3.0
# 1048563   10656     1580     4.0
# 1048564   10656     1584     4.0
# 1048565   10656     1586     3.0
# 1048566   10656     1587     4.0
# 1048567   10656     1593     2.0
# 1048568   10656     1597     3.0
# 1048569   10656     1606     2.0
# 1048570   10656     1608     2.0
# 1048571   10656     1610     3.0
# 1048572   10656     1614     3.0
# 1048573   10656     1616     1.0
# 1048574   10656     1617     4.0
# 1048575  200000      300     5.0
#
# [1048576 rows x 3 columns]

# %%
def userresult(num,algorithm):
    user_x = datasetmovies.copy()
    user_x = user_x.reset_index()
    # getting full dataset
    user_x['Estimate_Score'] = user_x['movieId'].apply(lambda x: algorithm.predict(num, x).est)

    user_x = user_x.drop('movieId', axis = 1)

    user_x = user_x.sort_values('Estimate_Score', ascending=False)
    return user_x

# %%
userresult(4800,algo).head(10)
# Out:
#                                                   title  \
# 5854      Lord of the Rings: The Two Towers, The (2002)
# 4898  Lord of the Rings: The Fellowship of the Ring,...
# 7042  Lord of the Rings: The Return of the King, The...
# 257           Star Wars: Episode IV - A New Hope (1977)
# 2706                                   Airplane! (1980)
# 1171  Star Wars: Episode V - The Empire Strikes Back...
# 1173  Raiders of the Lost Ark (Indiana Jones and the...
# 843                               Godfather, The (1972)
# 1194                         Blues Brothers, The (1980)
# 1155                              Paths of Glory (1957)
#
#                               genres  Estimate_Score
# 5854               Adventure|Fantasy        4.666669
# 4898               Adventure|Fantasy        4.653481
# 7042  Action|Adventure|Drama|Fantasy        4.627518
# 257          Action|Adventure|Sci-Fi        4.584853
# 2706                          Comedy        4.503335
# 1171         Action|Adventure|Sci-Fi        4.469293
# 1173                Action|Adventure        4.436751
# 843                      Crime|Drama        4.428275
# 1194           Action|Comedy|Musical        4.386037
# 1155                       Drama|War        4.379819

# %%
userresult(5000,algo).head(10)
# Out:
#                                                   title  \
# 257           Star Wars: Episode IV - A New Hope (1977)
# 1173  Raiders of the Lost Ark (Indiana Jones and the...
# 1471  Austin Powers: International Man of Mystery (1...
# 1171  Star Wars: Episode V - The Empire Strikes Back...
# 220                                       Clerks (1994)
# 108                                   Braveheart (1995)
# 315                    Shawshank Redemption, The (1994)
# 1017                                    Die Hard (1988)
# 293                                 Pulp Fiction (1994)
# 1945                         Saving Private Ryan (1998)
#
#                            genres  Estimate_Score
# 257       Action|Adventure|Sci-Fi        5.000000
# 1173             Action|Adventure        5.000000
# 1471      Action|Adventure|Comedy        4.979927
# 1171      Action|Adventure|Sci-Fi        4.909303
# 220                        Comedy        4.829663
# 108              Action|Drama|War        4.813576
# 315                   Crime|Drama        4.798143
# 1017        Action|Crime|Thriller        4.790618
# 293   Comedy|Crime|Drama|Thriller        4.778193
# 1945             Action|Drama|War        4.777121

# %%
userresult(247,algo).head(10)
# Out:
#                                                    title  \
# 625          Land and Freedom (Tierra y libertad) (1995)
# 3189                         Boondock Saints, The (2000)
# 16808      Castaway on the Moon (Kimssi pyoryugi) (2009)
# 1856                 Best Years of Our Lives, The (1946)
# 4338                       Sweet Smell of Success (1957)
# 39432                                Planet Earth (2006)
# 6430   Pirates of the Caribbean: The Curse of the Bla...
# 18766                              Civil War, The (1990)
# 888                         It Happened One Night (1934)
# 6502                                   Umberto D. (1952)
#
#                                 genres  Estimate_Score
# 625                          Drama|War        4.864094
# 3189       Action|Crime|Drama|Thriller        4.763609
# 16808             Comedy|Drama|Romance        4.725522
# 1856                         Drama|War        4.708511
# 4338                   Drama|Film-Noir        4.698266
# 39432                      Documentary        4.696256
# 6430   Action|Adventure|Comedy|Fantasy        4.683621
# 18766                  Documentary|War        4.662194
# 888                     Comedy|Romance        4.658199
# 6502                             Drama        4.647698

# %%
import socket

# %%
s = socket.socket()         # Create a socket object
host = socket.gethostname() # Get local machine name
port = 8082                # Reserve a port for your service.
s.bind(("localhost", port))        # Bind to the port
s.listen(5)                 # Now wait for client connection.
while True:
    c, addr = s.accept()     # Establish connection with client.
    numer = randint(1,9000)
    print('Got connection from', addr)
    data = c.recv(1024).decode("ASCII")
    datalist = data.split("-")
    newlist = datalist[1].split("_")
    for i in newlist:
        ass = i.split("@")
        chan = []
        chan.append(datalist[0])
        chan.extend(ass)
        some = pd.DataFrame([chan],columns=['userId','movieId','rating'])
        dataset.append(some)   
    final = userresult(numer,algo).head(10)
    title = final["title"].values.tolist()
    genre = final["genres"].values.tolist()
    str = ''
    for i in range(0,10):
        str = str + title[i] + "@" + genre[i] + "-"
    print(str)    
    c.send(str.encode('ASCII'))
    c.close()
    break
s.close()
# Out:
# Got connection from ('127.0.0.1', 60504)
# Citizen Kane (1941)@Drama|Mystery-Raising Arizona (1987)@Comedy-Being John Malkovich (1999)@Comedy|Drama|Fantasy-Sting, The (1973)@Comedy|Crime-Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)@Comedy|War-Monty Python and the Holy Grail (1975)@Adventure|Comedy|Fantasy-Up (2009)@Adventure|Animation|Children|Drama-Usual Suspects, The (1995)@Crime|Mystery|Thriller-Departed, The (2006)@Crime|Drama|Thriller-American Beauty (1999)@Drama|Romance-
